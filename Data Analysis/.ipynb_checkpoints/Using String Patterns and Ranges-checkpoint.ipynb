# %% [markdown]
# #### Retrieving rows from a table
# ![retriving%20rows.PNG](attachment:retriving%20rows.PNG)

# %%
# %load_ext sql

# %%
# %sql sqlite:///bookstore.db

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table';
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('Book',)]

# %%
# %%sql
# SELECT * FROM Book LIMIT 10;
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('B1', 'Getting started with DB2 Express-C', 1, 2010, 24.99, '978-0-98006283-1-1', 300, 'DB-A02', 'Teaches you the fundamentals'),
#  ('B2', 'Database Fundamentals', 1, 2010, 24.99, '978-0-98666283-5-1', 280, 'DB-A01', 'Teaches you the essentials of databases'),
#  ('B3', 'Getting started with DB2 App Dev', 1, 2011, 35.99, '978-0-98086283-4-1', 345, 'DB-A03', 'Teaches you advanced app development'),
#  ('B4', 'Getting started with WAS CE', 1, 2010, 49.99, '978-0-98946283-3-1', 458, 'DB-A04', 'Teaches you the essentials of WAS CE'),
#  ('B5', 'Advanced DB2 for Developers', 2, 2012, 55.99, '978-0-98006283-5-1', 380, 'DB-A05', 'Deep dive into DB2 development'),
#  ('B6', 'Cloud Databases Simplified', 1, 2013, 29.99, '978-0-98006283-6-1', 250, 'DB-A06', 'Introduction to cloud databases'),
# ...

# %%
# %%sql
# -- Create the Book table
# CREATE TABLE Book (
#     Book_ID TEXT PRIMARY KEY,
#     Title TEXT,
#     Edition INTEGER,
#     Year INTEGER,
#     Price REAL,
#     ISBN TEXT,
#     Pages INTEGER,
#     Aisle TEXT,
#     Description TEXT
# );
#
# -- Insert data into the Book table
# INSERT INTO Book (Book_ID, Title, Edition, Year, Price, ISBN, Pages, Aisle, Description) VALUES
# ('B1', 'Getting started with DB2 Express-C', 1, 2010, 24.99, '978-0-98006283-1-1', 300, 'DB-A02', 'Teaches you the fundamentals'),
# ('B2', 'Database Fundamentals', 1, 2010, 24.99, '978-0-98666283-5-1', 280, 'DB-A01', 'Teaches you the essentials of databases'),
# ('B3', 'Getting started with DB2 App Dev', 1, 2011, 35.99, '978-0-98086283-4-1', 345, 'DB-A03', 'Teaches you advanced app development'),
# ('B4', 'Getting started with WAS CE', 1, 2010, 49.99, '978-0-98946283-3-1', 458, 'DB-A04', 'Teaches you the essentials of WAS CE'),
# -- Additional rows
# ('B5', 'Advanced DB2 for Developers', 2, 2012, 55.99, '978-0-98006283-5-1', 380, 'DB-A05', 'Deep dive into DB2 development'),
# ('B6', 'Cloud Databases Simplified', 1, 2013, 29.99, '978-0-98006283-6-1', 250, 'DB-A06', 'Introduction to cloud databases'),
# ('B7', 'Mastering SQL Queries', 3, 2014, 44.99, '978-0-98006283-7-1', 420, 'DB-A07', 'A comprehensive guide to SQL'),
# ('B8', 'Big Data and Hadoop', 1, 2015, 59.99, '978-0-98006283-8-1', 500, 'DB-A08', 'An introduction to big data technologies'),
# ('B9', 'Data Mining Fundamentals', 2, 2016, 48.99, '978-0-98006283-9-1', 320, 'DB-A09', 'Learn the basics of data mining'),
# ('B10', 'Introduction to Machine Learning', 1, 2017, 64.99, '978-0-98006283-10-1', 600, 'DB-A10', 'Introduction to machine learning concepts'),
# -- Add many more rows like these
# ('B11', 'Python for Data Science', 2, 2018, 34.99, '978-0-98006283-11-1', 280, 'DB-A11', 'Python programming for data science'),
# ('B12', 'Deep Learning with TensorFlow', 1, 2019, 74.99, '978-0-98006283-12-1', 700, 'DB-A12', 'A guide to deep learning with TensorFlow'),
# ('B13', 'AI and Robotics', 1, 2020, 84.99, '978-0-98006283-13-1', 750, 'DB-A13', 'Introduction to AI and robotics'),
# -- Continue adding rows up to 100
# ('B100', 'Cybersecurity Essentials', 1, 2023, 89.99, '978-0-98006283-100-1', 550, 'DB-A100', 'A guide to cybersecurity essentials');

# %%
# %sql
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db

# %%
# %sql SELECT book_id, title FROM Book
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('B1', 'Getting started with DB2 Express-C'),
#  ('B2', 'Database Fundamentals'),
#  ('B3', 'Getting started with DB2 App Dev'),
#  ('B4', 'Getting started with WAS CE'),
#  ('B5', 'Advanced DB2 for Developers'),
#  ('B6', 'Cloud Databases Simplified'),
#  ('B7', 'Mastering SQL Queries'),
#  ('B8', 'Big Data and Hadoop'),
#  ('B9', 'Data Mining Fundamentals'),
#  ('B10', 'Introduction to Machine Learning'),
#  ('B11', 'Python for Data Science'),
#  ('B12', 'Deep Learning with TensorFlow'),
#  ('B13', 'AI and Robotics'),
#  ('B14', 'Book Title 14'),
#  ('B15', 'Book Title 15'),
#  ('B16', 'Book Title 16'),
#  ('B17', 'Book Title 17'),
#  ('B18', 'Book Title 18'),
#  ('B19', 'Book Title 19'),
#  ('B20', 'Book Title 20'),
#  ('B21', 'Book Title 21'),
#  ('B22', 'Book Title 22'),
#  ('B23', 'Book Title 23'),
#  ('B24', 'Book Title 24'),
#  ('B25', 'Book Title 25'),
# ...

# %%
# %%sql
# SELECT book_id, title FROM Book where book_id = "B1"
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('B1', 'Getting started with DB2 Express-C')]

# %% [markdown]
# #### The main purpose of a database management system is not just to store the data, but also facilitate retrieval of the data
# - The WHERE clause always requires a predicate, which is a condition that evaluates to true, false or unknown.
# - In a relational database, we can use string patterns to search data rows that match this condition.

# %% [markdown]
# #### Retrieving rows - using a String Pattern

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS Author (
#     Author_ID TEXT PRIMARY KEY,
#     First_Name TEXT,
#     Last_Name TEXT,
#     Country TEXT
# );
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# []

# %%
# %%sql
#
# INSERT INTO Author (Author_ID, First_Name, Last_Name, Country)
# VALUES
#     ('A1', 'John', 'Smith', 'USA'),
#     ('A2', 'Jane', 'Doe', 'UK'),
#     ('A3', 'Emily', 'Johnson', 'Canada'),
#     ('A4', 'Michael', 'Brown', 'Australia'),
#     ('A5', 'Lisa', 'White', 'Germany'),
#     ('A6', 'Robert', 'Williams', 'France'),
#     ('A7', 'Sarah', 'Miller', 'Brazil'),
#     ('A8', 'David', 'Anderson', 'USA'),
#     ('A9', 'Emma', 'Taylor', 'Italy'),
#     ('A10', 'James', 'Thomas', 'South Africa'),
#     ('A11', 'Sophia', 'Moore', 'India'),
#     ('A12', 'Benjamin', 'Clark', 'Japan'),
#     ('A13', 'Charlotte', 'Lee', 'China'),
#     ('A14', 'Daniel', 'Walker', 'Mexico'),
#     ('A15', 'Olivia', 'Martin', 'Spain'),
#     ('A16', 'Henry', 'Garcia', 'Argentina'),
#     ('A17', 'Amelia', 'Lopez', 'Colombia'),
#     ('A18', 'Mason', 'Gonzalez', 'Portugal'),
#     ('A19', 'Ava', 'Perez', 'Russia'),
#     ('A20', 'Elijah', 'Sanchez', 'Netherlands');
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# 20 rows affected.
# []

# %%
# %%sql
# SELECT First_Name from Author
# WHERE First_Name like "R%"
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('Robert',)]

# %% [markdown]
# #### The like predicate is used in a WHERE clause to search for a pattern in a column. The percent sign is used to define missing letters. The percent sign can be placed before the pattern, after the pattern, or both before and after the pattern
# - The percent sign is called a wildcard character. A wildcard character is used to substitute other characters.
# - For example, select first name from author, where firstname like 'R%'. This will return all rows in the author table whose author's first name starts with the letter R.

# %%
# %%sql
# select title, pages from Book
# WHERE PAGES>=290 and PAGES <=300;
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('Getting started with DB2 Express-C', 300),
#  ('Book Title 90', 290),
#  ('Book Title 91', 291),
#  ('Book Title 92', 292),
#  ('Book Title 93', 293),
#  ('Book Title 94', 294),
#  ('Book Title 95', 295),
#  ('Book Title 96', 296),
#  ('Book Title 97', 297),
#  ('Book Title 98', 298),
#  ('Book Title 99', 299),
#  ('Book Title 100', 300)]

# %% [markdown]
# ####  Instead of using the comparison operators greater than or equal to, we use the comparison operator 'between and.' 'Between and' compares two values.

# %%
# %%sql
# select title,pages from Book
# where  pages between 290 and 300;
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('Getting started with DB2 Express-C', 300),
#  ('Book Title 90', 290),
#  ('Book Title 91', 291),
#  ('Book Title 92', 292),
#  ('Book Title 93', 293),
#  ('Book Title 94', 294),
#  ('Book Title 95', 295),
#  ('Book Title 96', 296),
#  ('Book Title 97', 297),
#  ('Book Title 98', 298),
#  ('Book Title 99', 299),
#  ('Book Title 100', 300)]

# %% [markdown]
# #### Retrieving rows - using a set of values

# %%
# %%sql
# select First_Name, Last_Name, country from author
# where country = "UK" Or country = "USA"
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('John', 'Smith', 'USA'), ('Jane', 'Doe', 'UK'), ('David', 'Anderson', 'USA')]

# %% [markdown]
# #### The IN operator allows us to specify a set of values in a WHERE clause. This operator takes a list of expressions to compare against

# %%
# %%sql
#
# select First_Name, Last_Name, country from author
# where country IN("UK","USA","BR")
# Out:
#    sqlite:///CVD.db
#    sqlite:///DA.db
#  * sqlite:///bookstore.db
#    sqlite:///sf-film-locations.db
# Done.
# [('John', 'Smith', 'USA'), ('Jane', 'Doe', 'UK'), ('David', 'Anderson', 'USA')]

# %% [markdown]
# #### You can use the WHERE clause to refine your query results.
#
# - The search condition of the WHERE clause uses a predicate to refine the search.
# - You can use the wildcard character (%) as a substitute for unknown characters in a pattern.
# - You can use BETWEEN ... AND ... to specify a range of numbers.
# - You can sort query results into ascending or descending order, using the ORDER BY clause to specify the column to sort on.
# - You can group query results by using the GROUP BY clause.

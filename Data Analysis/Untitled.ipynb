# %%
# %load_ext sql
# %sql sqlite:///CVD.db

# %%
# %%sql
#
# DROP TABLE IF EXISTS PATIENTS;
# DROP TABLE IF EXISTS MEDICAL_HISTORY;
# DROP TABLE IF EXISTS MEDICAL_PROCEDURES;
# DROP TABLE IF EXISTS MEDICAL_DEPARTMENTS;
# DROP TABLE IF EXISTS MEDICAL_LOCATIONS;
#
#
# CREATE TABLE PATIENTS (
#   PATIENT_ID CHAR(9) NOT NULL,
#   FIRST_NAME VARCHAR(15) NOT NULL,
#   LAST_NAME VARCHAR(15) NOT NULL,
#   SSN CHAR(9),
#   BIRTH_DATE DATE,
#   SEX CHAR,
#   ADDRESS VARCHAR(30),
#   DEPT_ID CHAR(9) NOT NULL,
#   PRIMARY KEY (PATIENT_ID)
# );
#
# CREATE TABLE MEDICAL_HISTORY (
#   MEDICAL_HISTORY_ID CHAR(9) NOT NULL,
#   PATIENT_ID CHAR(9) NOT NULL,
#   DIAGNOSIS_DATE DATE,
#   DIAGNOSIS_CODE VARCHAR(10),
#   MEDICAL_CONDITION VARCHAR(100),
#   DEPT_ID CHAR(9),
#   PRIMARY KEY (MEDICAL_HISTORY_ID)
# );
#
# CREATE TABLE MEDICAL_PROCEDURES (
#   PROCEDURE_ID CHAR(9) NOT NULL,
#   PROCEDURE_NAME VARCHAR(30),
#   PROCEDURE_DATE DATE,
#   PATIENT_ID CHAR(9) NOT NULL,
#   DEPT_ID CHAR(9),
#   PRIMARY KEY (PROCEDURE_ID)
# );
#
# CREATE TABLE MEDICAL_DEPARTMENTS (
#   DEPT_ID CHAR(9) NOT NULL,
#   DEPT_NAME VARCHAR(15),
#   MANAGER_ID CHAR(9),
#   LOCATION_ID CHAR(9),
#   PRIMARY KEY (DEPT_ID)
# );
#
# CREATE TABLE MEDICAL_LOCATIONS (
#   LOCATION_ID CHAR(9) NOT NULL,
#   DEPT_ID CHAR(9) NOT NULL,
#   LOCATION_NAME VARCHAR(50),
#   PRIMARY KEY (LOCATION_ID, DEPT_ID)
# );
# Out:
#  * sqlite:///CVD.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# #### ![dbcd.PNG](attachment:dbcd.PNG)

# %% [markdown]
# - A database is a repository of data that provides functionality for adding, modifying, and querying the data.
# - SQL is a language used to query or retrieve data from a relational database.
# - The Relational Model is the most used data model for databases because it allows for data independence.
# - The primary key of a relational table uniquely identifies each tuple or row, preventing duplication of data and providing a way of defining relationships between tables.
# - SQL statements fall into two different categories: Data Definition Language (DDL) statements and Data Manipulation Language (DML) statements.

# %% [markdown]
# #### What is the function of a primary key?
# 1. The primary key is used to grant access to a table.
# 2. The primary key is used to identify any rows in the table that contain NULL values.
# 3. The primary key uniquely identifies each row in a table.
# 4. The primary key enables you to add data to columns.
#
# #### 2 Question 2 True or False: Data Manipulation Language statements like INSERT, SELECT, UPDATE, and DELETE are used to read and modify data.
# - True
# - False
#
# #### 3.Question 3 Data Definition Language (or DDL) statements are used to define, change, or delete database objects such as tables. Which of the following statements are all DDL statements?
# 1. SELECT and DELETE
# 2. SELECT, INSERT, UPDATE
# 3. CREATE, ALTER, DROP
# 4. INSERT and UPDATE
#
# #### 4. Question 4 Which of the following queries will change the data type of an existing column (phone) to the varchar data type?
# 1. ALTER COLUMN phone SET DATA TYPE VARCHAR(20);
# 2. ALTER TABLE author ALTER COLUMN phone SET TYPE VARCHAR(20);
# 3. ALTER TABLE author MODIFY phone VARCHAR(20);
# 4. ALTER TABLE author ALTER COLUMN phone DATA TYPE = VARCHAR(20);
#
# #### 5. Question 5 The five basic SQL commands are:
# 1. CREATE, SELECT, INSERT, UPDATE, DELETE
# 2. None of the above
# 3. CREATE, INSERT, RETRIEVE, MODIFY, DELETE
# 4. SELECT, COPY, PASTE, INSERT, ALTER

# %% [markdown]
# #### Which of the following statements about a database is/are correct?
# 1. A database is a logically coherent collection of data with some inherent meaning
# 2. Data can only be added and queried from a database but not modified.
# 3. Only SQL can be used to query data in a database.
# 4. All of the above
#
# #### 2. Question 2 Attributes of an entity become ________ in a table.
# - rows
# - keys
# - constraints
# - columns
#
# #### 3. Question 3 The CREATE TABLE statement is a ________.
# 1. DML statement
# 2. DDL statement
# 3. DQL statement
# 4. All of the above
#
# #### 4. Question 4 Which command is used for removing a table and all its data from the database?
#
# 1. CREATE command
# 2. ALTER table command
# 3. TRUNCATE table command
# 4. DROP table command
#
# #### 5. Question 5 What would be the correct syntax to add a column ‘ID’ that contains 7 character alpha-numeric values to a database table ‘Employees’ using MySQL?
#
# 1.  ALTER Employees ADD COLUMN ID varchar(7)
# 2. ALTER TABLE Employees ADD ID char(7)
# 3. ALTER TABLE COLUMN Employees ID char(7)
# 4. ALTER Employees TABLE ADD ID char

# %%
# !pip install datasette
# Out:
# ...
#   Obtaining dependency information for datasette from https://files.pythonhosted.org/packages/99/f4/ef9a0ef94390eff7201397d50891735cc3da9d67ae1db0e2edbf7c04d433/datasette-0.64.8-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for asgiref>=3.2.10 from https://files.pythonhosted.org/packages/39/e3/893e8757be2612e6c266d9bb58ad2e3651524b5b40cf56761e985a28b13e/asgiref-3.8.1-py3-none-any.whl.metadata
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Obtaining dependency information for click-default-group>=1.2.3 from https://files.pythonhosted.org/packages/2c/1a/aff8bb287a4b1400f69e09a53bd65de96aa5cee5691925b38731c67fc695/click_default_group-1.2.4-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for hupper>=1.9 from https://files.pythonhosted.org/packages/86/7d/3888833e4f5ea56af4a9935066ec09a83228e533d7b8877f65889d706ee4/hupper-1.12.1-py3-none-any.whl.metadata
# ...

# %% [markdown]
# ### Why Data sciene and sql
# 1. SQL plays a virtal role
# 2. Extract insights from large dataset.
#
# - SQL plays a vital role in data science work flow.
# - Enabling professionals to extract valuable insight from large, intrcate datasets.

# %% [markdown]
# - ![powerful.PNG](attachment:powerful.PNG)
# - SQL is powerful, globally relevant (in industry and academia), and widely used by most data scientists today

# %% [markdown]
# ###
# - Module 1: simple SQL for data manipulation in a database table.
# - Module 2: data definition statements and how to create our database tables.
# - Module 3: built-in functions, sub-queries, and working with multiple tables.
# - module 4: explore Python for accessing databases using Jupyter Notebooks.
# - Module 5: primarily focuses on a project based on real-world data
# - Module 6: advanced concepts like Stored Procedures, Views, ACID Transactions, Inner & Outer JOINs.scenarios,

# %% [markdown]
# ### What is SQL?
# - ![sql.PNG](attachment:sql.PNG)
# - SQL is a language used for relational databases to query or get data out of a database.
# - SQL is also referred to as SQL and is short for its original name, Structured Query Language.
# - SQL Is a language used for a database to query data.
#
# ### what is data and what is a database?
#
# - Data is a collection of facts in the form of words, numbers, or even pictures.
# - Data is one of the most critical assets of any business.
# - It is used and collected practically everywhere. Your bank stores data about you, your name, address, phone number, account numbers, etc.
# - Your credit card company and your PayPal accounts also store data about you. Data is important so it needs to be secure and it needs to be stored and access quickly.

# %% [markdown]
# ### ![data.PNG](attachment:data.PNG)

# %% [markdown]
# ### What is a database?
# - Databases are everywhere and used every day, but they are largely taken for granted.
# - A database is a repository of data, it is a program that stores data.
# - A database also provides the functionality for adding, modifying, and querying that data.
# - There are different kinds of databases of different requirements.
# - ![db.PNG](attachment:db.PNG)

# %% [markdown]
# ### Relational Database
# - The data can be stored in various forms.
# - When data is stored in tabular form, the data is organized in tables like in a spreadsheet, which is columns and rows, that's relational database.
# - The columns contain properties about the item such as LastName, FirstName, e-mail address, city.
# - A table is a collection of related things, like a list of employees or a list of book authors.
# - In a relational database, you can form relationships between tables.
# - ![relationdb.PNG](attachment:relationdb.PNG)

# %% [markdown]
# ### DBMS
# -  A database is a repository of data
# - A set of software tools for the data in the database is called a database management system, or DBMS, for short.
# - The terms database, database server, database system, data server and database management systems are often used interchangeably.
# - ![dbms.PNG](attachment:dbms.PNG)

# %% [markdown]
# ### RDBMS
#  relational database management system or RDBMS.
#  - RDBMS is a set of software tools that controls the data, such as access, organization, and storage.
#  - RDBMS serves as the backbone of applications in many industries, including banking, transportation, health, and so on.
#  - Examples of relational database management systems are MySQL, Oracle database, DB2 warehouse, and DB2 on Cloud
#  - ![rdbms.PNG](attachment:rdbms.PNG)
